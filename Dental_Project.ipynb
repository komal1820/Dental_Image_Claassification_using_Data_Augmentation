# %%
# !pip install imgaug
# Out:
# Requirement already satisfied: imgaug in /usr/local/lib/python3.10/dist-packages (0.4.0)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.16.0)
# Requirement already satisfied: numpy>=1.15 in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.25.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from imgaug) (1.11.4)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from imgaug) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from imgaug) (3.7.1)
# Requirement already satisfied: scikit-image>=0.14.2 in /usr/local/lib/python3.10/dist-packages (from imgaug) (0.19.3)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from imgaug) (4.8.0.76)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.31.6)
# Requirement already satisfied: Shapely in /usr/local/lib/python3.10/dist-packages (from imgaug) (2.0.4)
# Requirement already satisfied: networkx>=2.2 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (3.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (2024.4.18)
# Requirement already satisfied: PyWavelets>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (1.6.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.14.2->imgaug) (24.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->imgaug) (2.8.2)

# %%
import tensorflow as tf
import numpy as np
tf.random.set_seed(100)

from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, GlobalAveragePooling2D, Activation, Input
from tensorflow.keras.optimizers import Adam
#from tensorflow.keras.callbacks import  EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.optimizers import SGD #Stochatic Gradient Descent
#from keras.utils.vis_utils import plot_model
from keras.models import load_model
from keras.utils import to_categorical
from tensorflow.keras.layers import Dropout
from keras import backend as K
from tensorflow.keras.utils import Sequence

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import cv2
import random
import os
import glob

import imgaug as ia
ia.seed(1)

# %%
# %matplotlib inline
from imgaug.augmentables.bbs import BoundingBox, BoundingBoxesOnImage
from imgaug import augmenters as iaa


import imageio
import pandas as pd
import numpy as np
import re #Regular Expression

import shutil

# %%
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
classes_list = sorted(['Cavity',  'Fillings', 'Implant','Impacted Tooth'])

import pandas as pd
labels_df = pd.read_csv("/content/drive/MyDrive/Dental22/_newlabels.csv")
labels_df.head(20)
# Out:
#                 filename  width  height           class  xmin  ymin  xmax  \
# 0        Filliings01.jpg    512     256        Fillings   357   129   401
# 1          Implant01.jpg    512     256         Implant   220    66   237
# 2   Impacted_tooth01.jpg    512     256  Impacted Tooth    87   158   121
# 3          Implant02.jpg    512     256         Implant   246    95   264
# 4          Implant03.jpg    512     256         Implant   163   124   196
# 5   Impacted_tooth02.jpg    512     256  Impacted Tooth    70   136   103
# 6        Filliings02.jpg    512     256        Fillings   170   161   198
# 7          Implant04.jpg    512     256         Implant   191   157   212
# 8           Cavity01.jpg    512     256          Cavity   124   136   158
# 9          Implant05.jpg    512     256         Implant   111   148   141
# 10       Filliings03.jpg    512     256        Fillings   161   104   190
# 11         Implant06.jpg    512     256         Implant   212    90   226
# 12         Implant07.jpg    512     256         Implant   195   169   209
# 13  Impacted_tooth03.jpg    512     256  Impacted Tooth   383   149   418
# 14         Implant08.jpg    512     256         Implant   324   127   368
# 15          Cavity02.jpg    512     256          Cavity    84    99   120
# 16         Implant09.jpg    512     256         Implant   315   149   348
# 17  Impacted_tooth04.jpg    512     256  Impacted Tooth    86   112   125
# 18       Filliings04.jpg    512     256        Fillings   141   114   166
# 19          Cavity03.jpg    512     256          Cavity   100   143   136
#
#     ymax
# 0    180
# 1    121
# 2    188
# 3    136
# 4    173
# 5    171
# 6    210
# 7    202
# 8    179
# 9    191
# 10   150
# 11   133
# 12   212
# 13   180
# 14   187
# 15   151
# 16   196
# 17   154
# 18   152
# 19   186

# %%
# Function to convert bounding box image into DataFrame
def bounding_boxes_to_df(bounding_boxes_object):

    # Converting the Bounding Box Objects to Array
    bounding_boxes_array = bounding_boxes_object.to_xyxy_array()

    # Converting the array into DataFrame
    df_bounding_boxes = pd.DataFrame(bounding_boxes_array,
                                     columns=['xmin', 'ymin', 'xmax', 'ymax'])

    # Return the DataFrame
    return df_bounding_boxes

# %%
# Define all the Augmentations you want to apply to your dataset
# We're setting random `n` agumentations to 2.
image_augmentations = iaa.SomeOf( 2,
    [
    # Scale the Images, Increasing or decreasing the size of the image
    iaa.Affine(scale=(0.5, 1.5)),

    # Rotate the Images to -60 and 60 degrees
    iaa.Affine(rotate=(-60, 60)),

    # Shift the Image
    iaa.Affine(translate_percent={"x":(-0.3, 0.3),"y":(-0.3, 0.3)}),

    # Fliping the image horizontally
    iaa.Fliplr(1),

    # Increase or decrease the brightness
    iaa.Multiply((0.5, 1.5)),

    # Add Gaussian Blur
    iaa.GaussianBlur(sigma=(1.0, 3.0)),

    # Add Gaussian Noise
    iaa.AdditiveGaussianNoise(scale=(0.03*255, 0.05*255))

])

# %%
image_directory = '/content/drive/MyDrive/Dental22'

# %%
np.bool = np.bool_
def image_aug(df, images_path, aug_images_path, augmentor, multiple = 4):

    # Fill this DataFrame with image attributes
    augmentations_df = pd.DataFrame(
        columns=['filename','width','height','class', 'xmin', 'ymin', 'xmax',
                 'ymax'])

    # Group the data by filenames
    grouped_df = df.groupby('filename')

    # Create the directory for all augmentated images
    if not os.path.exists(aug_images_path):
      os.mkdir(aug_images_path)

    # Create directories for each class of augmentated images
    for folder in df['class'].unique():
      if not os.path.exists(os.path.join(aug_images_path, folder)):
        os.mkdir(os.path.join(aug_images_path, folder))

    for i in range(multiple):

      # Post Fix we add to the each different augmentation of one image
      image_postfix = str(i)

      # Loop to perform the augmentations
      for filename in df['filename'].unique():
        augmented_path = os.path.join(aug_images_path, df[df['filename'] == filename]['class'].iloc[0], filename) + image_postfix + '.jpg'

        # Take one image at a time with its information
        single_image = grouped_df.get_group(filename)
        single_image = single_image.reset_index()
        single_image = single_image.drop(['index'], axis=1)

        # Read the image
        image = imageio.v2.imread(os.path.join(images_path, filename))

        # Get bounding box
        bounding_box_array = single_image.drop(['filename', 'width', 'height',
                                                'class'], axis=1).values

        # Give the bounding box to imgaug library
        bounding_box = BoundingBoxesOnImage.from_xyxy_array(bounding_box_array,
                                                            shape=image.shape)

        # Perform random 2 Augmentations
        image_aug, bounding_box_aug = augmentor(image=image,
                                                bounding_boxes=bounding_box)

        # Discard the the bounding box going out the image completely
        bounding_box_aug = bounding_box_aug.remove_out_of_image()

        # Clip the bounding box that are only partially out of th image
        bounding_box_aug = bounding_box_aug.clip_out_of_image()

        # Get rid of the the image if bounding box was discarded
        if re.findall('Image...', str(bounding_box_aug)) == ['Image([]']:
            pass

        else:

          # Create the augmented image file
          imageio.imwrite(augmented_path, image_aug)

          # Update the image width and height after augmentation
          info_df = single_image.drop(['xmin', 'ymin', 'xmax', 'ymax'], axis=1)
          for index, _ in info_df.iterrows():
              info_df.at[index, 'width'] = image_aug.shape[1]
              info_df.at[index, 'height'] = image_aug.shape[0]

          # Add the prefix to each image to differentiate if required
          info_df['filename'] = info_df['filename'].apply(lambda x: x + image_postfix + '.jpg')

          # Create the augmented bounding boxes dataframe
          bounding_box_df = bounding_boxes_to_df(bounding_box_aug)

          # Concatenate the filenames, height, width and bounding boxes
          aug_df = pd.concat([info_df, bounding_box_df], axis=1)

          # Add all the information to augmentations_df we initialized above
          augmentations_df = pd.concat([augmentations_df, aug_df])

    # Remove index
    augmentations_df = augmentations_df.reset_index()
    augmentations_df = augmentations_df.drop(['index'], axis=1)

    # Return the Dataframe
    return augmentations_df

augmented_images_df = image_aug(labels_df, image_directory, 'aug_images',
                                image_augmentations)

# %%
import warnings

# Suppress deprecation warnings for np.bool
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
augmented_images_df = augmented_images_df.sort_values('filename', ignore_index= True)
augmented_images_df.to_csv('//content/drive/MyDrive/Dental22/_annotations.csv')

# Check Dataset Size
print('Our total dataset Size before the augmentations was: ', len(labels_df))
print('Our total dataset Size after the augmentations is: ', len(augmented_images_df))
# Out:
# Our total dataset Size before the augmentations was:  71
# Our total dataset Size after the augmentations is:  282

# %%
def preprocess_dataset(image_folder, classes_list, df, image_size = 100,):


  # Lists that will contain the whole dataset
  labels = []
  boxes = []
  img_list = []

  # Get height and width of each image in the datafame
  h = df['height']
  w = df['width']

  # Create a copy of the labels in the dataframe
  labels = list(df['class'])

  # Create a copy of the bounding box values and also normalize them
  for x1, y1, x2, y2 in zip(list(df['xmin']/w), list(df['ymin']/h),
                            list(df['xmax']/w), list(df['ymax']/h)):

    arr = [x1, y1, x2, y2]
    boxes.append(arr)

  # We loop over each class and its labels
  for class_folder in classes_list:

    # Set our images directory
    image_dir = os.path.join(image_folder, class_folder)

    # Annotation and Image files
    img_files = sorted(os.listdir(image_dir))

    # Loop over each of the image and its label
    for image_file in img_files:

      # Full path Image
      img_path = os.path.join(image_dir, image_file)

      # Read the image
      img  = cv2.imread(img_path)

      # Resize all images to a fix size
      image = cv2.resize(img, (image_size, image_size))

      # Convert the image from BGR to RGB
      image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

      # Normalize the image by dividing it by 255.0
      image = image.astype("float") / 255.0

      # Append it to the list of images
      img_list.append(image)

  return labels, boxes, img_list

# %%
# All images will resized to 100, 100
image_size = 100

# Get Augmented images and bounding boxes
labels, boxes, img_list = preprocess_dataset('aug_images', classes_list,
                                             augmented_images_df)

# %%
# Convert labels to integers, then one hot encode them
label_encoder = LabelEncoder() #To convert text into numerical data for model's better understanding
integer_labels = label_encoder.fit_transform(labels)
onehot_labels = to_categorical(integer_labels) #Converting categorical data in the form of numbers for model's better understanding

# %%
# Create a Matplotlib figure
plt.figure(figsize=(20,20));
# Generate a random sample of images each time the cell is run
random_range = random.sample(range(1, len(img_list)), 20)

for iteration, i in enumerate(random_range, 1):

    # Bounding box of each image
    a1, b1, a2, b2 = boxes[i];

    # Rescaling the boundig box values to match the image size
    x1 = a1 * image_size
    x2 = a2 * image_size
    y1 = b1 * image_size
    y2 = b2 * image_size

    # The image to visualize
    image = img_list[i]

    # Draw bounding boxes on the image
    cv2.rectangle(image, (int(x1),int(y1)),
          (int(x2),int(y2)),
                  (0,255,0),
                  3);

    # Clip the values to 0-1 and draw the sample of images
    image = np.clip(img_list[i], 0, 1)
    plt.subplot(4, 5, iteration);
    plt.imshow(image);
    plt.axis('off');

# %%
train_images, val_images, train_labels, \
val_labels, train_boxes, val_boxes = train_test_split( np.array(img_list),
                np.array(onehot_labels), np.array(boxes), test_size = 0.1,
                random_state = 43)

print('Total Training Images: {}, Total Validation Images: {}'.format(
    len(train_images), len(val_images) ))
# Out:
# Total Training Images: 253, Total Validation Images: 29

# %%
# Load the NasNetMobile Model, make sure to exclude the top for transfer learning
N_mobile = tf.keras.applications.NASNetMobile( input_tensor = Input(
    shape=(image_size, image_size, 3)),
    include_top=False,
    weights='imagenet')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/nasnet/NASNet-mobile-no-top.h5
# 19993432/19993432 [==============================] - 1s 0us/step

# %%
# Let's create a function that will construct our model
def create_model(no_of_classes):

    # Freeze the whole model
    N_mobile.trainable = False

    # Start by taking the output feature maps from NASNETMobile
    base_model_output = N_mobile.output

    # Convert to a single-dimensional vector by Global Average Pooling.

    # We could also use Flatten()(x) but GAP is more effective, it reduces
    # Parameters and controls overfitting.
    flattened_output = GlobalAveragePooling2D()(base_model_output)

    # Create our Classification Head, final layer contains
    # Ouput units = no. classes
    class_prediction = Dense(256, activation="relu")(flattened_output)
    class_prediction = Dense(128, activation="relu")(class_prediction )
    class_prediction = Dropout(0.2)(class_prediction)
    class_prediction = Dense(64, activation="relu")(class_prediction)
    class_prediction = Dropout(0.2)(class_prediction )
    class_prediction = Dense(32, activation="relu")(class_prediction)
    class_prediction = Dense(no_of_classes, activation='softmax',
                             name="class_output")(class_prediction)

    # Create Our Localization Head, final layer contains 4 nodes for x1,y1,x2,y2
    # Respectively.
    box_output = Dense(256, activation="relu")(flattened_output)
    box_output = Dense(128, activation="relu")(box_output)
    box_output = Dropout(0.2)(box_output )

    box_output = Dense(64, activation="relu")(box_output)
    box_output = Dropout(0.2)(box_output )

    box_output = Dense(32, activation="relu")(box_output)
    box_predictions = Dense(4, activation='sigmoid',
                            name= "box_output")(box_output)

    # Now combine the two heads
    model = Model(inputs=N_mobile.input, outputs= [box_predictions,
                                                   class_prediction])

    return model

# Create the model for 3 classes, Elephant, Butterfly, Cougar-Face
model = create_model(4); print("Model Created")
# Out:
# Model Created

# %%
# Here for each head we will define a different loss, we will define it
# Like a dictionary.

# For classification we will have cateogirical crossentropy
# For the bouding boxes we will have mean squared error
losses = {
    "box_output": "mean_squared_error",
    "class_output": "categorical_crossentropy"
    }

# Here you can give more or less weightage to each loss.

# If you think that detection is harder then the classification then you can
# Try assinging it more weight
loss_weights = {
    "box_output": 1.0,
    "class_output": 1.0
    }

# Set the Metrics
# For the class labels we want to know the Accuracy
# And for the bounding boxes we need to know the Mean squared error
metrics = {
    'class_output': 'accuracy',
    'box_output':  'mse'
    }

# # We will be using early stopping to stop the model if total val loss does not
# # Decrease by 0.001 in 40 epochs
# stop = EarlyStopping(monitor = "val_loss", min_delta = 0.0001, patience = 3,
#                     restore_best_weights = True
#                      )

# # Change the learning rate according to number of epochs to boost learning
# reduce_lr = ReduceLROnPlateau(monitor = "val_loss", factor = 0.0002,
#                               patience = 30, min_lr = 1e-7, verbose = 1)

# Initialize Optimizer
opt = SGD(learning_rate = 1e-7, momentum = 0.9)

# Compile the model with Adam optimizer
model.compile(optimizer = opt, loss = losses, loss_weights = loss_weights,
    metrics = metrics)

# %%
print(train_boxes.shape)
print(train_labels.shape)
# Out:
# (253, 4)
# (253, 4)

# %%
# Train the Model
history = model.fit(x = train_images,
                    y= {
                        "box_output": train_boxes,
                        "class_output": train_labels
                        },
                    validation_data=(
                        val_images,
                        {
                          "box_output": val_boxes,
                          "class_output": val_labels
                          }), batch_size = 32, epochs = 2000)
# Out:
# Epoch 1/2000
# 8/8 [==============================] - 27s 1s/step - loss: 1.5158 - box_output_loss: 0.0676 - class_output_loss: 1.4481 - box_output_mse: 0.0676 - class_output_accuracy: 0.3162 - val_loss: 1.5585 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4750 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 2/2000
# 8/8 [==============================] - 6s 778ms/step - loss: 1.5671 - box_output_loss: 0.0711 - class_output_loss: 1.4960 - box_output_mse: 0.0711 - class_output_accuracy: 0.2806 - val_loss: 1.5584 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4749 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 3/2000
# 8/8 [==============================] - 4s 545ms/step - loss: 1.5167 - box_output_loss: 0.0705 - class_output_loss: 1.4462 - box_output_mse: 0.0705 - class_output_accuracy: 0.2372 - val_loss: 1.5584 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4749 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 4/2000
# 8/8 [==============================] - 6s 851ms/step - loss: 1.5277 - box_output_loss: 0.0693 - class_output_loss: 1.4583 - box_output_mse: 0.0693 - class_output_accuracy: 0.2530 - val_loss: 1.5583 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4748 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 5/2000
# 8/8 [==============================] - 4s 569ms/step - loss: 1.5073 - box_output_loss: 0.0698 - class_output_loss: 1.4375 - box_output_mse: 0.0698 - class_output_accuracy: 0.2767 - val_loss: 1.5582 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4747 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 6/2000
# 8/8 [==============================] - 5s 576ms/step - loss: 1.4590 - box_output_loss: 0.0686 - class_output_loss: 1.3904 - box_output_mse: 0.0686 - class_output_accuracy: 0.3004 - val_loss: 1.5581 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4746 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 7/2000
# 8/8 [==============================] - 6s 749ms/step - loss: 1.5231 - box_output_loss: 0.0667 - class_output_loss: 1.4564 - box_output_mse: 0.0667 - class_output_accuracy: 0.3083 - val_loss: 1.5581 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4746 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 8/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.5134 - box_output_loss: 0.0691 - class_output_loss: 1.4443 - box_output_mse: 0.0691 - class_output_accuracy: 0.2964 - val_loss: 1.5580 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4745 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 9/2000
# 8/8 [==============================] - 5s 610ms/step - loss: 1.5565 - box_output_loss: 0.0684 - class_output_loss: 1.4882 - box_output_mse: 0.0684 - class_output_accuracy: 0.2411 - val_loss: 1.5579 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4744 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 10/2000
# 8/8 [==============================] - 6s 703ms/step - loss: 1.5243 - box_output_loss: 0.0689 - class_output_loss: 1.4555 - box_output_mse: 0.0689 - class_output_accuracy: 0.2806 - val_loss: 1.5578 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4743 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 11/2000
# 8/8 [==============================] - 5s 573ms/step - loss: 1.5133 - box_output_loss: 0.0692 - class_output_loss: 1.4441 - box_output_mse: 0.0692 - class_output_accuracy: 0.2846 - val_loss: 1.5577 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4742 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 12/2000
# 8/8 [==============================] - 5s 662ms/step - loss: 1.5402 - box_output_loss: 0.0685 - class_output_loss: 1.4717 - box_output_mse: 0.0685 - class_output_accuracy: 0.3004 - val_loss: 1.5576 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4741 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 13/2000
# 8/8 [==============================] - 5s 664ms/step - loss: 1.4793 - box_output_loss: 0.0686 - class_output_loss: 1.4107 - box_output_mse: 0.0686 - class_output_accuracy: 0.3320 - val_loss: 1.5575 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4740 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 14/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.5492 - box_output_loss: 0.0703 - class_output_loss: 1.4789 - box_output_mse: 0.0703 - class_output_accuracy: 0.2767 - val_loss: 1.5574 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4739 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 15/2000
# 8/8 [==============================] - 6s 735ms/step - loss: 1.4984 - box_output_loss: 0.0683 - class_output_loss: 1.4301 - box_output_mse: 0.0683 - class_output_accuracy: 0.2688 - val_loss: 1.5574 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4739 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 16/2000
# 8/8 [==============================] - 5s 611ms/step - loss: 1.5185 - box_output_loss: 0.0689 - class_output_loss: 1.4497 - box_output_mse: 0.0689 - class_output_accuracy: 0.2885 - val_loss: 1.5573 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4738 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 17/2000
# 8/8 [==============================] - 4s 539ms/step - loss: 1.5194 - box_output_loss: 0.0699 - class_output_loss: 1.4495 - box_output_mse: 0.0699 - class_output_accuracy: 0.2925 - val_loss: 1.5572 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4737 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 18/2000
# 8/8 [==============================] - 7s 916ms/step - loss: 1.4876 - box_output_loss: 0.0693 - class_output_loss: 1.4183 - box_output_mse: 0.0693 - class_output_accuracy: 0.2964 - val_loss: 1.5571 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4736 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 19/2000
# 8/8 [==============================] - 5s 655ms/step - loss: 1.5474 - box_output_loss: 0.0695 - class_output_loss: 1.4780 - box_output_mse: 0.0695 - class_output_accuracy: 0.2490 - val_loss: 1.5570 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4735 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 20/2000
# 8/8 [==============================] - 4s 536ms/step - loss: 1.5565 - box_output_loss: 0.0701 - class_output_loss: 1.4863 - box_output_mse: 0.0701 - class_output_accuracy: 0.3043 - val_loss: 1.5569 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4734 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 21/2000
# 8/8 [==============================] - 6s 753ms/step - loss: 1.5749 - box_output_loss: 0.0704 - class_output_loss: 1.5044 - box_output_mse: 0.0704 - class_output_accuracy: 0.2727 - val_loss: 1.5568 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4733 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 22/2000
# 8/8 [==============================] - 5s 582ms/step - loss: 1.5528 - box_output_loss: 0.0689 - class_output_loss: 1.4839 - box_output_mse: 0.0689 - class_output_accuracy: 0.2806 - val_loss: 1.5567 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4732 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 23/2000
# 8/8 [==============================] - 4s 541ms/step - loss: 1.5254 - box_output_loss: 0.0718 - class_output_loss: 1.4537 - box_output_mse: 0.0718 - class_output_accuracy: 0.2688 - val_loss: 1.5566 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4731 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 24/2000
# 8/8 [==============================] - 7s 883ms/step - loss: 1.5396 - box_output_loss: 0.0710 - class_output_loss: 1.4686 - box_output_mse: 0.0710 - class_output_accuracy: 0.2727 - val_loss: 1.5565 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4730 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 25/2000
# 8/8 [==============================] - 6s 714ms/step - loss: 1.5101 - box_output_loss: 0.0665 - class_output_loss: 1.4435 - box_output_mse: 0.0665 - class_output_accuracy: 0.2846 - val_loss: 1.5564 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4729 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 26/2000
# 8/8 [==============================] - 4s 562ms/step - loss: 1.5358 - box_output_loss: 0.0695 - class_output_loss: 1.4663 - box_output_mse: 0.0695 - class_output_accuracy: 0.2569 - val_loss: 1.5563 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4728 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 27/2000
# 8/8 [==============================] - 6s 776ms/step - loss: 1.5076 - box_output_loss: 0.0691 - class_output_loss: 1.4385 - box_output_mse: 0.0691 - class_output_accuracy: 0.2451 - val_loss: 1.5562 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4727 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 28/2000
# 8/8 [==============================] - 4s 543ms/step - loss: 1.5157 - box_output_loss: 0.0721 - class_output_loss: 1.4436 - box_output_mse: 0.0721 - class_output_accuracy: 0.2925 - val_loss: 1.5562 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4727 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 29/2000
# 8/8 [==============================] - 5s 620ms/step - loss: 1.5519 - box_output_loss: 0.0709 - class_output_loss: 1.4809 - box_output_mse: 0.0709 - class_output_accuracy: 0.2490 - val_loss: 1.5561 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4726 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 30/2000
# 8/8 [==============================] - 6s 684ms/step - loss: 1.5460 - box_output_loss: 0.0672 - class_output_loss: 1.4788 - box_output_mse: 0.0672 - class_output_accuracy: 0.2569 - val_loss: 1.5560 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4725 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 31/2000
# 8/8 [==============================] - 5s 577ms/step - loss: 1.5584 - box_output_loss: 0.0704 - class_output_loss: 1.4880 - box_output_mse: 0.0704 - class_output_accuracy: 0.2925 - val_loss: 1.5559 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4724 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 32/2000
# 8/8 [==============================] - 5s 693ms/step - loss: 1.4928 - box_output_loss: 0.0690 - class_output_loss: 1.4238 - box_output_mse: 0.0690 - class_output_accuracy: 0.3281 - val_loss: 1.5558 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4723 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 33/2000
# 8/8 [==============================] - 5s 654ms/step - loss: 1.4985 - box_output_loss: 0.0705 - class_output_loss: 1.4280 - box_output_mse: 0.0705 - class_output_accuracy: 0.2372 - val_loss: 1.5557 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4722 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 34/2000
# 8/8 [==============================] - 4s 549ms/step - loss: 1.5051 - box_output_loss: 0.0682 - class_output_loss: 1.4368 - box_output_mse: 0.0682 - class_output_accuracy: 0.2767 - val_loss: 1.5556 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4721 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 35/2000
# 8/8 [==============================] - 6s 814ms/step - loss: 1.5796 - box_output_loss: 0.0702 - class_output_loss: 1.5094 - box_output_mse: 0.0702 - class_output_accuracy: 0.2925 - val_loss: 1.5555 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4721 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 36/2000
# 8/8 [==============================] - 5s 575ms/step - loss: 1.5131 - box_output_loss: 0.0692 - class_output_loss: 1.4439 - box_output_mse: 0.0692 - class_output_accuracy: 0.2292 - val_loss: 1.5555 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4720 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 37/2000
# 8/8 [==============================] - 4s 550ms/step - loss: 1.5213 - box_output_loss: 0.0690 - class_output_loss: 1.4522 - box_output_mse: 0.0690 - class_output_accuracy: 0.2688 - val_loss: 1.5554 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4719 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 38/2000
# 8/8 [==============================] - 6s 837ms/step - loss: 1.5060 - box_output_loss: 0.0694 - class_output_loss: 1.4366 - box_output_mse: 0.0694 - class_output_accuracy: 0.2727 - val_loss: 1.5553 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4718 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 39/2000
# 8/8 [==============================] - 5s 579ms/step - loss: 1.5042 - box_output_loss: 0.0679 - class_output_loss: 1.4363 - box_output_mse: 0.0679 - class_output_accuracy: 0.2846 - val_loss: 1.5552 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4717 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 40/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.5451 - box_output_loss: 0.0672 - class_output_loss: 1.4779 - box_output_mse: 0.0672 - class_output_accuracy: 0.2885 - val_loss: 1.5551 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4716 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 41/2000
# 8/8 [==============================] - 6s 857ms/step - loss: 1.5120 - box_output_loss: 0.0693 - class_output_loss: 1.4427 - box_output_mse: 0.0693 - class_output_accuracy: 0.2885 - val_loss: 1.5551 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4716 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 42/2000
# 8/8 [==============================] - 4s 550ms/step - loss: 1.5382 - box_output_loss: 0.0688 - class_output_loss: 1.4694 - box_output_mse: 0.0688 - class_output_accuracy: 0.2925 - val_loss: 1.5550 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4715 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 43/2000
# 8/8 [==============================] - 4s 574ms/step - loss: 1.5571 - box_output_loss: 0.0715 - class_output_loss: 1.4856 - box_output_mse: 0.0715 - class_output_accuracy: 0.2648 - val_loss: 1.5549 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4714 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 44/2000
# 8/8 [==============================] - 6s 824ms/step - loss: 1.4887 - box_output_loss: 0.0674 - class_output_loss: 1.4213 - box_output_mse: 0.0674 - class_output_accuracy: 0.2530 - val_loss: 1.5548 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4713 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 45/2000
# 8/8 [==============================] - 4s 543ms/step - loss: 1.5064 - box_output_loss: 0.0693 - class_output_loss: 1.4371 - box_output_mse: 0.0693 - class_output_accuracy: 0.2530 - val_loss: 1.5548 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4713 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 46/2000
# 8/8 [==============================] - 6s 827ms/step - loss: 1.5724 - box_output_loss: 0.0696 - class_output_loss: 1.5028 - box_output_mse: 0.0696 - class_output_accuracy: 0.2648 - val_loss: 1.5547 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4712 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 47/2000
# 8/8 [==============================] - 6s 784ms/step - loss: 1.5045 - box_output_loss: 0.0698 - class_output_loss: 1.4347 - box_output_mse: 0.0698 - class_output_accuracy: 0.3281 - val_loss: 1.5546 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4711 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 48/2000
# 8/8 [==============================] - 4s 572ms/step - loss: 1.4999 - box_output_loss: 0.0680 - class_output_loss: 1.4319 - box_output_mse: 0.0680 - class_output_accuracy: 0.2688 - val_loss: 1.5545 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4710 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 49/2000
# 8/8 [==============================] - 6s 718ms/step - loss: 1.5046 - box_output_loss: 0.0694 - class_output_loss: 1.4352 - box_output_mse: 0.0694 - class_output_accuracy: 0.2846 - val_loss: 1.5544 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4709 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 50/2000
# 8/8 [==============================] - 5s 602ms/step - loss: 1.4962 - box_output_loss: 0.0702 - class_output_loss: 1.4260 - box_output_mse: 0.0702 - class_output_accuracy: 0.2806 - val_loss: 1.5543 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4708 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 51/2000
# 8/8 [==============================] - 4s 546ms/step - loss: 1.4802 - box_output_loss: 0.0666 - class_output_loss: 1.4136 - box_output_mse: 0.0666 - class_output_accuracy: 0.2925 - val_loss: 1.5542 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4708 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 52/2000
# 8/8 [==============================] - 6s 807ms/step - loss: 1.5183 - box_output_loss: 0.0689 - class_output_loss: 1.4494 - box_output_mse: 0.0689 - class_output_accuracy: 0.3043 - val_loss: 1.5541 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4707 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 53/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.5355 - box_output_loss: 0.0694 - class_output_loss: 1.4661 - box_output_mse: 0.0694 - class_output_accuracy: 0.2451 - val_loss: 1.5540 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4706 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 54/2000
# 8/8 [==============================] - 5s 685ms/step - loss: 1.5150 - box_output_loss: 0.0702 - class_output_loss: 1.4448 - box_output_mse: 0.0702 - class_output_accuracy: 0.2411 - val_loss: 1.5540 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4705 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 55/2000
# 8/8 [==============================] - 8s 946ms/step - loss: 1.5717 - box_output_loss: 0.0709 - class_output_loss: 1.5008 - box_output_mse: 0.0709 - class_output_accuracy: 0.2885 - val_loss: 1.5539 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4704 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 56/2000
# 8/8 [==============================] - 4s 572ms/step - loss: 1.5398 - box_output_loss: 0.0703 - class_output_loss: 1.4695 - box_output_mse: 0.0703 - class_output_accuracy: 0.2885 - val_loss: 1.5538 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4703 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 57/2000
# 8/8 [==============================] - 4s 573ms/step - loss: 1.5034 - box_output_loss: 0.0688 - class_output_loss: 1.4346 - box_output_mse: 0.0688 - class_output_accuracy: 0.3083 - val_loss: 1.5537 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4702 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 58/2000
# 8/8 [==============================] - 6s 814ms/step - loss: 1.5336 - box_output_loss: 0.0708 - class_output_loss: 1.4628 - box_output_mse: 0.0708 - class_output_accuracy: 0.2885 - val_loss: 1.5536 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4702 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 59/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.5103 - box_output_loss: 0.0692 - class_output_loss: 1.4410 - box_output_mse: 0.0692 - class_output_accuracy: 0.3123 - val_loss: 1.5535 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4701 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 60/2000
# 8/8 [==============================] - 5s 580ms/step - loss: 1.5971 - box_output_loss: 0.0685 - class_output_loss: 1.5286 - box_output_mse: 0.0685 - class_output_accuracy: 0.2332 - val_loss: 1.5534 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4700 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 61/2000
# 8/8 [==============================] - 6s 762ms/step - loss: 1.5287 - box_output_loss: 0.0703 - class_output_loss: 1.4584 - box_output_mse: 0.0703 - class_output_accuracy: 0.2885 - val_loss: 1.5533 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4699 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 62/2000
# 8/8 [==============================] - 5s 575ms/step - loss: 1.5013 - box_output_loss: 0.0701 - class_output_loss: 1.4312 - box_output_mse: 0.0701 - class_output_accuracy: 0.3320 - val_loss: 1.5532 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4698 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 63/2000
# 8/8 [==============================] - 5s 648ms/step - loss: 1.5516 - box_output_loss: 0.0692 - class_output_loss: 1.4825 - box_output_mse: 0.0692 - class_output_accuracy: 0.2609 - val_loss: 1.5531 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4697 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 64/2000
# 8/8 [==============================] - 6s 674ms/step - loss: 1.5706 - box_output_loss: 0.0724 - class_output_loss: 1.4983 - box_output_mse: 0.0724 - class_output_accuracy: 0.2925 - val_loss: 1.5531 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4696 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 65/2000
# 8/8 [==============================] - 4s 572ms/step - loss: 1.4956 - box_output_loss: 0.0708 - class_output_loss: 1.4247 - box_output_mse: 0.0708 - class_output_accuracy: 0.3360 - val_loss: 1.5530 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4695 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 66/2000
# 8/8 [==============================] - 6s 760ms/step - loss: 1.5215 - box_output_loss: 0.0684 - class_output_loss: 1.4531 - box_output_mse: 0.0684 - class_output_accuracy: 0.2569 - val_loss: 1.5529 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4694 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 67/2000
# 8/8 [==============================] - 5s 567ms/step - loss: 1.5068 - box_output_loss: 0.0696 - class_output_loss: 1.4372 - box_output_mse: 0.0696 - class_output_accuracy: 0.3281 - val_loss: 1.5528 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4693 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 68/2000
# 8/8 [==============================] - 4s 546ms/step - loss: 1.4870 - box_output_loss: 0.0717 - class_output_loss: 1.4153 - box_output_mse: 0.0717 - class_output_accuracy: 0.2885 - val_loss: 1.5527 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4692 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 69/2000
# 8/8 [==============================] - 7s 862ms/step - loss: 1.5330 - box_output_loss: 0.0688 - class_output_loss: 1.4642 - box_output_mse: 0.0688 - class_output_accuracy: 0.2806 - val_loss: 1.5527 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4692 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 70/2000
# 8/8 [==============================] - 4s 574ms/step - loss: 1.5126 - box_output_loss: 0.0694 - class_output_loss: 1.4432 - box_output_mse: 0.0694 - class_output_accuracy: 0.2609 - val_loss: 1.5526 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4691 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 71/2000
# 8/8 [==============================] - 4s 566ms/step - loss: 1.5745 - box_output_loss: 0.0709 - class_output_loss: 1.5036 - box_output_mse: 0.0709 - class_output_accuracy: 0.2609 - val_loss: 1.5525 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4690 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 72/2000
# 8/8 [==============================] - 6s 823ms/step - loss: 1.4780 - box_output_loss: 0.0681 - class_output_loss: 1.4099 - box_output_mse: 0.0681 - class_output_accuracy: 0.3162 - val_loss: 1.5524 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4689 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 73/2000
# 8/8 [==============================] - 4s 544ms/step - loss: 1.4986 - box_output_loss: 0.0691 - class_output_loss: 1.4295 - box_output_mse: 0.0691 - class_output_accuracy: 0.2727 - val_loss: 1.5523 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4688 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 74/2000
# 8/8 [==============================] - 6s 819ms/step - loss: 1.4701 - box_output_loss: 0.0681 - class_output_loss: 1.4020 - box_output_mse: 0.0681 - class_output_accuracy: 0.3320 - val_loss: 1.5522 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4688 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 75/2000
# 8/8 [==============================] - 6s 771ms/step - loss: 1.5148 - box_output_loss: 0.0684 - class_output_loss: 1.4465 - box_output_mse: 0.0684 - class_output_accuracy: 0.3202 - val_loss: 1.5522 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4687 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 76/2000
# 8/8 [==============================] - 4s 547ms/step - loss: 1.5245 - box_output_loss: 0.0691 - class_output_loss: 1.4553 - box_output_mse: 0.0691 - class_output_accuracy: 0.3043 - val_loss: 1.5521 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4686 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 77/2000
# 8/8 [==============================] - 5s 665ms/step - loss: 1.4865 - box_output_loss: 0.0685 - class_output_loss: 1.4180 - box_output_mse: 0.0685 - class_output_accuracy: 0.2846 - val_loss: 1.5520 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4685 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 78/2000
# 8/8 [==============================] - 5s 656ms/step - loss: 1.5697 - box_output_loss: 0.0694 - class_output_loss: 1.5003 - box_output_mse: 0.0694 - class_output_accuracy: 0.3083 - val_loss: 1.5519 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4684 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 79/2000
# 8/8 [==============================] - 4s 545ms/step - loss: 1.5361 - box_output_loss: 0.0696 - class_output_loss: 1.4665 - box_output_mse: 0.0696 - class_output_accuracy: 0.2648 - val_loss: 1.5518 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4684 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 80/2000
# 8/8 [==============================] - 6s 746ms/step - loss: 1.5328 - box_output_loss: 0.0692 - class_output_loss: 1.4636 - box_output_mse: 0.0692 - class_output_accuracy: 0.3083 - val_loss: 1.5518 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4683 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 81/2000
# 8/8 [==============================] - 5s 583ms/step - loss: 1.5073 - box_output_loss: 0.0668 - class_output_loss: 1.4406 - box_output_mse: 0.0668 - class_output_accuracy: 0.2806 - val_loss: 1.5517 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4682 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 82/2000
# 8/8 [==============================] - 4s 548ms/step - loss: 1.5182 - box_output_loss: 0.0691 - class_output_loss: 1.4490 - box_output_mse: 0.0691 - class_output_accuracy: 0.2806 - val_loss: 1.5516 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4681 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 83/2000
# 8/8 [==============================] - 6s 807ms/step - loss: 1.5244 - box_output_loss: 0.0677 - class_output_loss: 1.4567 - box_output_mse: 0.0677 - class_output_accuracy: 0.2372 - val_loss: 1.5515 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4680 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 84/2000
# 8/8 [==============================] - 7s 828ms/step - loss: 1.5038 - box_output_loss: 0.0710 - class_output_loss: 1.4328 - box_output_mse: 0.0710 - class_output_accuracy: 0.3320 - val_loss: 1.5514 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4680 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 85/2000
# 8/8 [==============================] - 4s 550ms/step - loss: 1.4964 - box_output_loss: 0.0714 - class_output_loss: 1.4250 - box_output_mse: 0.0714 - class_output_accuracy: 0.3004 - val_loss: 1.5514 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4679 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 86/2000
# 8/8 [==============================] - 7s 864ms/step - loss: 1.4876 - box_output_loss: 0.0681 - class_output_loss: 1.4194 - box_output_mse: 0.0681 - class_output_accuracy: 0.2925 - val_loss: 1.5513 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4678 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 87/2000
# 8/8 [==============================] - 5s 581ms/step - loss: 1.4905 - box_output_loss: 0.0695 - class_output_loss: 1.4210 - box_output_mse: 0.0695 - class_output_accuracy: 0.3043 - val_loss: 1.5512 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4677 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 88/2000
# 8/8 [==============================] - 5s 580ms/step - loss: 1.5291 - box_output_loss: 0.0677 - class_output_loss: 1.4614 - box_output_mse: 0.0677 - class_output_accuracy: 0.2609 - val_loss: 1.5511 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4676 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 89/2000
# 8/8 [==============================] - 6s 758ms/step - loss: 1.5221 - box_output_loss: 0.0684 - class_output_loss: 1.4537 - box_output_mse: 0.0684 - class_output_accuracy: 0.2885 - val_loss: 1.5510 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4676 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 90/2000
# 8/8 [==============================] - 4s 573ms/step - loss: 1.5748 - box_output_loss: 0.0713 - class_output_loss: 1.5036 - box_output_mse: 0.0713 - class_output_accuracy: 0.2490 - val_loss: 1.5510 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4675 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 91/2000
# 8/8 [==============================] - 5s 616ms/step - loss: 1.5386 - box_output_loss: 0.0708 - class_output_loss: 1.4678 - box_output_mse: 0.0708 - class_output_accuracy: 0.2688 - val_loss: 1.5509 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4674 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 92/2000
# 8/8 [==============================] - 6s 721ms/step - loss: 1.5087 - box_output_loss: 0.0698 - class_output_loss: 1.4389 - box_output_mse: 0.0698 - class_output_accuracy: 0.2885 - val_loss: 1.5508 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4673 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 93/2000
# 8/8 [==============================] - 4s 547ms/step - loss: 1.5434 - box_output_loss: 0.0696 - class_output_loss: 1.4738 - box_output_mse: 0.0696 - class_output_accuracy: 0.2648 - val_loss: 1.5507 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4672 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 94/2000
# 8/8 [==============================] - 5s 677ms/step - loss: 1.5549 - box_output_loss: 0.0691 - class_output_loss: 1.4858 - box_output_mse: 0.0691 - class_output_accuracy: 0.2846 - val_loss: 1.5506 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4671 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 95/2000
# 8/8 [==============================] - 6s 664ms/step - loss: 1.5142 - box_output_loss: 0.0719 - class_output_loss: 1.4423 - box_output_mse: 0.0719 - class_output_accuracy: 0.3043 - val_loss: 1.5505 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4670 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 96/2000
# 8/8 [==============================] - 5s 574ms/step - loss: 1.5108 - box_output_loss: 0.0683 - class_output_loss: 1.4425 - box_output_mse: 0.0683 - class_output_accuracy: 0.2609 - val_loss: 1.5504 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4669 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 97/2000
# 8/8 [==============================] - 6s 831ms/step - loss: 1.4824 - box_output_loss: 0.0710 - class_output_loss: 1.4115 - box_output_mse: 0.0710 - class_output_accuracy: 0.2806 - val_loss: 1.5503 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4669 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 98/2000
# 8/8 [==============================] - 5s 576ms/step - loss: 1.5395 - box_output_loss: 0.0692 - class_output_loss: 1.4703 - box_output_mse: 0.0692 - class_output_accuracy: 0.2451 - val_loss: 1.5503 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4668 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 99/2000
# 8/8 [==============================] - 5s 572ms/step - loss: 1.4758 - box_output_loss: 0.0660 - class_output_loss: 1.4099 - box_output_mse: 0.0660 - class_output_accuracy: 0.3123 - val_loss: 1.5502 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4667 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 100/2000
# 8/8 [==============================] - 6s 851ms/step - loss: 1.4965 - box_output_loss: 0.0683 - class_output_loss: 1.4282 - box_output_mse: 0.0683 - class_output_accuracy: 0.2885 - val_loss: 1.5501 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4666 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 101/2000
# 8/8 [==============================] - 5s 683ms/step - loss: 1.4696 - box_output_loss: 0.0694 - class_output_loss: 1.4002 - box_output_mse: 0.0694 - class_output_accuracy: 0.2688 - val_loss: 1.5500 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4666 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 102/2000
# 8/8 [==============================] - 7s 858ms/step - loss: 1.5327 - box_output_loss: 0.0696 - class_output_loss: 1.4631 - box_output_mse: 0.0696 - class_output_accuracy: 0.3202 - val_loss: 1.5500 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4665 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 103/2000
# 8/8 [==============================] - 5s 566ms/step - loss: 1.4753 - box_output_loss: 0.0701 - class_output_loss: 1.4052 - box_output_mse: 0.0701 - class_output_accuracy: 0.3004 - val_loss: 1.5499 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4664 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 104/2000
# 8/8 [==============================] - 5s 576ms/step - loss: 1.5126 - box_output_loss: 0.0688 - class_output_loss: 1.4438 - box_output_mse: 0.0688 - class_output_accuracy: 0.2885 - val_loss: 1.5498 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4663 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 105/2000
# 8/8 [==============================] - 7s 876ms/step - loss: 1.5121 - box_output_loss: 0.0690 - class_output_loss: 1.4432 - box_output_mse: 0.0690 - class_output_accuracy: 0.2569 - val_loss: 1.5497 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4663 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 106/2000
# 8/8 [==============================] - 4s 551ms/step - loss: 1.5314 - box_output_loss: 0.0685 - class_output_loss: 1.4628 - box_output_mse: 0.0685 - class_output_accuracy: 0.2846 - val_loss: 1.5497 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4662 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 107/2000
# 8/8 [==============================] - 4s 548ms/step - loss: 1.4787 - box_output_loss: 0.0709 - class_output_loss: 1.4078 - box_output_mse: 0.0709 - class_output_accuracy: 0.3043 - val_loss: 1.5496 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4661 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 108/2000
# 8/8 [==============================] - 7s 862ms/step - loss: 1.5068 - box_output_loss: 0.0711 - class_output_loss: 1.4358 - box_output_mse: 0.0711 - class_output_accuracy: 0.2767 - val_loss: 1.5495 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4660 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 109/2000
# 8/8 [==============================] - 5s 578ms/step - loss: 1.5025 - box_output_loss: 0.0707 - class_output_loss: 1.4318 - box_output_mse: 0.0707 - class_output_accuracy: 0.3162 - val_loss: 1.5494 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4660 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 110/2000
# 8/8 [==============================] - 4s 572ms/step - loss: 1.4578 - box_output_loss: 0.0695 - class_output_loss: 1.3883 - box_output_mse: 0.0695 - class_output_accuracy: 0.3202 - val_loss: 1.5494 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4659 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 111/2000
# 8/8 [==============================] - 7s 830ms/step - loss: 1.5121 - box_output_loss: 0.0690 - class_output_loss: 1.4431 - box_output_mse: 0.0690 - class_output_accuracy: 0.3281 - val_loss: 1.5493 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4658 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 112/2000
# 8/8 [==============================] - 6s 831ms/step - loss: 1.5130 - box_output_loss: 0.0691 - class_output_loss: 1.4439 - box_output_mse: 0.0691 - class_output_accuracy: 0.2569 - val_loss: 1.5492 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4657 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 113/2000
# 8/8 [==============================] - 7s 900ms/step - loss: 1.5335 - box_output_loss: 0.0697 - class_output_loss: 1.4638 - box_output_mse: 0.0697 - class_output_accuracy: 0.2846 - val_loss: 1.5491 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4656 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 114/2000
# 8/8 [==============================] - 4s 553ms/step - loss: 1.5181 - box_output_loss: 0.0695 - class_output_loss: 1.4486 - box_output_mse: 0.0695 - class_output_accuracy: 0.2885 - val_loss: 1.5490 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4656 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 115/2000
# 8/8 [==============================] - 4s 556ms/step - loss: 1.5024 - box_output_loss: 0.0701 - class_output_loss: 1.4322 - box_output_mse: 0.0701 - class_output_accuracy: 0.2767 - val_loss: 1.5490 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4655 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 116/2000
# 8/8 [==============================] - 6s 828ms/step - loss: 1.4877 - box_output_loss: 0.0673 - class_output_loss: 1.4204 - box_output_mse: 0.0673 - class_output_accuracy: 0.3083 - val_loss: 1.5489 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4654 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 117/2000
# 8/8 [==============================] - 4s 549ms/step - loss: 1.5303 - box_output_loss: 0.0713 - class_output_loss: 1.4590 - box_output_mse: 0.0713 - class_output_accuracy: 0.2846 - val_loss: 1.5488 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4654 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.2759
# Epoch 118/2000
# 8/8 [==============================] - 4s 546ms/step - loss: 1.5304 - box_output_loss: 0.0686 - class_output_loss: 1.4618 - box_output_mse: 0.0686 - class_output_accuracy: 0.2846 - val_loss: 1.5488 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4653 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 119/2000
# 8/8 [==============================] - 7s 853ms/step - loss: 1.5454 - box_output_loss: 0.0694 - class_output_loss: 1.4760 - box_output_mse: 0.0694 - class_output_accuracy: 0.2688 - val_loss: 1.5487 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4652 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 120/2000
# 8/8 [==============================] - 5s 581ms/step - loss: 1.5249 - box_output_loss: 0.0693 - class_output_loss: 1.4556 - box_output_mse: 0.0693 - class_output_accuracy: 0.2569 - val_loss: 1.5486 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4651 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 121/2000
# 8/8 [==============================] - 5s 580ms/step - loss: 1.4759 - box_output_loss: 0.0689 - class_output_loss: 1.4070 - box_output_mse: 0.0689 - class_output_accuracy: 0.2885 - val_loss: 1.5485 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4650 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 122/2000
# 8/8 [==============================] - 6s 782ms/step - loss: 1.5513 - box_output_loss: 0.0661 - class_output_loss: 1.4852 - box_output_mse: 0.0661 - class_output_accuracy: 0.2806 - val_loss: 1.5484 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4649 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 123/2000
# 8/8 [==============================] - 4s 549ms/step - loss: 1.4823 - box_output_loss: 0.0694 - class_output_loss: 1.4130 - box_output_mse: 0.0694 - class_output_accuracy: 0.3202 - val_loss: 1.5483 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4649 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 124/2000
# 8/8 [==============================] - 5s 708ms/step - loss: 1.5098 - box_output_loss: 0.0694 - class_output_loss: 1.4404 - box_output_mse: 0.0694 - class_output_accuracy: 0.2609 - val_loss: 1.5483 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4648 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 125/2000
# 8/8 [==============================] - 5s 645ms/step - loss: 1.5418 - box_output_loss: 0.0714 - class_output_loss: 1.4704 - box_output_mse: 0.0714 - class_output_accuracy: 0.2569 - val_loss: 1.5482 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4647 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 126/2000
# 8/8 [==============================] - 4s 549ms/step - loss: 1.5126 - box_output_loss: 0.0723 - class_output_loss: 1.4403 - box_output_mse: 0.0723 - class_output_accuracy: 0.2727 - val_loss: 1.5481 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4646 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 127/2000
# 8/8 [==============================] - 6s 761ms/step - loss: 1.5191 - box_output_loss: 0.0693 - class_output_loss: 1.4499 - box_output_mse: 0.0693 - class_output_accuracy: 0.2727 - val_loss: 1.5481 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4646 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 128/2000
# 8/8 [==============================] - 5s 597ms/step - loss: 1.5398 - box_output_loss: 0.0711 - class_output_loss: 1.4687 - box_output_mse: 0.0711 - class_output_accuracy: 0.2569 - val_loss: 1.5480 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4645 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 129/2000
# 8/8 [==============================] - 7s 827ms/step - loss: 1.5175 - box_output_loss: 0.0691 - class_output_loss: 1.4483 - box_output_mse: 0.0691 - class_output_accuracy: 0.2609 - val_loss: 1.5479 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4644 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 130/2000
# 8/8 [==============================] - 6s 783ms/step - loss: 1.5152 - box_output_loss: 0.0711 - class_output_loss: 1.4440 - box_output_mse: 0.0711 - class_output_accuracy: 0.2451 - val_loss: 1.5478 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4643 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 131/2000
# 8/8 [==============================] - 4s 550ms/step - loss: 1.5313 - box_output_loss: 0.0696 - class_output_loss: 1.4617 - box_output_mse: 0.0696 - class_output_accuracy: 0.2767 - val_loss: 1.5477 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4643 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 132/2000
# 8/8 [==============================] - 5s 696ms/step - loss: 1.5099 - box_output_loss: 0.0703 - class_output_loss: 1.4396 - box_output_mse: 0.0703 - class_output_accuracy: 0.2885 - val_loss: 1.5477 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4642 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 133/2000
# 8/8 [==============================] - 5s 656ms/step - loss: 1.5106 - box_output_loss: 0.0702 - class_output_loss: 1.4404 - box_output_mse: 0.0702 - class_output_accuracy: 0.2964 - val_loss: 1.5476 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4641 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 134/2000
# 8/8 [==============================] - 4s 550ms/step - loss: 1.5165 - box_output_loss: 0.0678 - class_output_loss: 1.4486 - box_output_mse: 0.0678 - class_output_accuracy: 0.2609 - val_loss: 1.5475 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4640 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 135/2000
# 8/8 [==============================] - 6s 736ms/step - loss: 1.5026 - box_output_loss: 0.0705 - class_output_loss: 1.4321 - box_output_mse: 0.0705 - class_output_accuracy: 0.2609 - val_loss: 1.5474 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4639 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 136/2000
# 8/8 [==============================] - 5s 591ms/step - loss: 1.5131 - box_output_loss: 0.0696 - class_output_loss: 1.4435 - box_output_mse: 0.0696 - class_output_accuracy: 0.2767 - val_loss: 1.5473 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4639 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 137/2000
# 8/8 [==============================] - 4s 548ms/step - loss: 1.4917 - box_output_loss: 0.0701 - class_output_loss: 1.4216 - box_output_mse: 0.0701 - class_output_accuracy: 0.3162 - val_loss: 1.5472 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4638 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 138/2000
# 8/8 [==============================] - 6s 765ms/step - loss: 1.5179 - box_output_loss: 0.0702 - class_output_loss: 1.4476 - box_output_mse: 0.0702 - class_output_accuracy: 0.3043 - val_loss: 1.5472 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4637 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 139/2000
# 8/8 [==============================] - 5s 600ms/step - loss: 1.5243 - box_output_loss: 0.0697 - class_output_loss: 1.4546 - box_output_mse: 0.0697 - class_output_accuracy: 0.2688 - val_loss: 1.5471 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4636 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 140/2000
# 8/8 [==============================] - 5s 576ms/step - loss: 1.5128 - box_output_loss: 0.0706 - class_output_loss: 1.4421 - box_output_mse: 0.0706 - class_output_accuracy: 0.2806 - val_loss: 1.5470 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4635 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 141/2000
# 8/8 [==============================] - 8s 1s/step - loss: 1.5309 - box_output_loss: 0.0700 - class_output_loss: 1.4609 - box_output_mse: 0.0700 - class_output_accuracy: 0.2648 - val_loss: 1.5469 - val_box_output_loss: 0.0835 - val_class_output_loss: 1.4634 - val_box_output_mse: 0.0835 - val_class_output_accuracy: 0.3103
# Epoch 142/2000
# ...
# Epoch 1955/2000
# 8/8 [==============================] - 5s 603ms/step - loss: 1.4762 - box_output_loss: 0.0675 - class_output_loss: 1.4087 - box_output_mse: 0.0675 - class_output_accuracy: 0.3043 - val_loss: 1.4312 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3481 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1956/2000
# 8/8 [==============================] - 6s 812ms/step - loss: 1.4417 - box_output_loss: 0.0699 - class_output_loss: 1.3718 - box_output_mse: 0.0699 - class_output_accuracy: 0.3478 - val_loss: 1.4311 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3481 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1957/2000
# 8/8 [==============================] - 5s 640ms/step - loss: 1.4401 - box_output_loss: 0.0682 - class_output_loss: 1.3719 - box_output_mse: 0.0682 - class_output_accuracy: 0.3320 - val_loss: 1.4311 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3480 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1958/2000
# 8/8 [==============================] - 5s 610ms/step - loss: 1.4498 - box_output_loss: 0.0715 - class_output_loss: 1.3783 - box_output_mse: 0.0715 - class_output_accuracy: 0.3636 - val_loss: 1.4310 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3480 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1959/2000
# 8/8 [==============================] - 7s 887ms/step - loss: 1.4800 - box_output_loss: 0.0697 - class_output_loss: 1.4103 - box_output_mse: 0.0697 - class_output_accuracy: 0.3162 - val_loss: 1.4310 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3479 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1960/2000
# 8/8 [==============================] - 5s 634ms/step - loss: 1.4572 - box_output_loss: 0.0689 - class_output_loss: 1.3883 - box_output_mse: 0.0689 - class_output_accuracy: 0.3399 - val_loss: 1.4310 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3479 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1961/2000
# 8/8 [==============================] - 5s 654ms/step - loss: 1.4562 - box_output_loss: 0.0707 - class_output_loss: 1.3856 - box_output_mse: 0.0707 - class_output_accuracy: 0.3202 - val_loss: 1.4309 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3479 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1962/2000
# 8/8 [==============================] - 6s 769ms/step - loss: 1.4561 - box_output_loss: 0.0672 - class_output_loss: 1.3889 - box_output_mse: 0.0672 - class_output_accuracy: 0.3320 - val_loss: 1.4309 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3478 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1963/2000
# 8/8 [==============================] - 5s 606ms/step - loss: 1.4258 - box_output_loss: 0.0682 - class_output_loss: 1.3576 - box_output_mse: 0.0682 - class_output_accuracy: 0.3281 - val_loss: 1.4308 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3478 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1964/2000
# 8/8 [==============================] - 6s 785ms/step - loss: 1.4516 - box_output_loss: 0.0686 - class_output_loss: 1.3829 - box_output_mse: 0.0686 - class_output_accuracy: 0.3004 - val_loss: 1.4308 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3477 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1965/2000
# 8/8 [==============================] - 7s 808ms/step - loss: 1.4797 - box_output_loss: 0.0702 - class_output_loss: 1.4095 - box_output_mse: 0.0702 - class_output_accuracy: 0.3241 - val_loss: 1.4308 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3477 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1966/2000
# 8/8 [==============================] - 6s 776ms/step - loss: 1.4760 - box_output_loss: 0.0708 - class_output_loss: 1.4053 - box_output_mse: 0.0708 - class_output_accuracy: 0.3241 - val_loss: 1.4307 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3477 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1967/2000
# 8/8 [==============================] - 6s 702ms/step - loss: 1.4661 - box_output_loss: 0.0692 - class_output_loss: 1.3969 - box_output_mse: 0.0692 - class_output_accuracy: 0.3004 - val_loss: 1.4307 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3476 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1968/2000
# 8/8 [==============================] - 5s 599ms/step - loss: 1.4556 - box_output_loss: 0.0693 - class_output_loss: 1.3862 - box_output_mse: 0.0693 - class_output_accuracy: 0.3557 - val_loss: 1.4306 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3476 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1969/2000
# 8/8 [==============================] - 7s 893ms/step - loss: 1.4901 - box_output_loss: 0.0678 - class_output_loss: 1.4223 - box_output_mse: 0.0678 - class_output_accuracy: 0.3241 - val_loss: 1.4306 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3475 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1970/2000
# 8/8 [==============================] - 5s 600ms/step - loss: 1.4457 - box_output_loss: 0.0697 - class_output_loss: 1.3761 - box_output_mse: 0.0697 - class_output_accuracy: 0.3281 - val_loss: 1.4305 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3475 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1971/2000
# 8/8 [==============================] - 5s 603ms/step - loss: 1.5024 - box_output_loss: 0.0710 - class_output_loss: 1.4314 - box_output_mse: 0.0710 - class_output_accuracy: 0.2885 - val_loss: 1.4305 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3475 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1972/2000
# 8/8 [==============================] - 7s 869ms/step - loss: 1.4657 - box_output_loss: 0.0697 - class_output_loss: 1.3960 - box_output_mse: 0.0697 - class_output_accuracy: 0.3439 - val_loss: 1.4305 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3474 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1973/2000
# 8/8 [==============================] - 5s 603ms/step - loss: 1.4741 - box_output_loss: 0.0690 - class_output_loss: 1.4050 - box_output_mse: 0.0690 - class_output_accuracy: 0.3202 - val_loss: 1.4304 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3474 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1974/2000
# 8/8 [==============================] - 6s 779ms/step - loss: 1.4551 - box_output_loss: 0.0668 - class_output_loss: 1.3883 - box_output_mse: 0.0668 - class_output_accuracy: 0.3557 - val_loss: 1.4304 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3473 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1975/2000
# 8/8 [==============================] - 6s 669ms/step - loss: 1.4338 - box_output_loss: 0.0699 - class_output_loss: 1.3639 - box_output_mse: 0.0699 - class_output_accuracy: 0.3478 - val_loss: 1.4303 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3473 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1976/2000
# 8/8 [==============================] - 5s 603ms/step - loss: 1.4798 - box_output_loss: 0.0699 - class_output_loss: 1.4099 - box_output_mse: 0.0699 - class_output_accuracy: 0.3083 - val_loss: 1.4303 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3472 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1977/2000
# 8/8 [==============================] - 7s 894ms/step - loss: 1.4587 - box_output_loss: 0.0692 - class_output_loss: 1.3895 - box_output_mse: 0.0692 - class_output_accuracy: 0.3202 - val_loss: 1.4303 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3472 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1978/2000
# 8/8 [==============================] - 5s 630ms/step - loss: 1.4723 - box_output_loss: 0.0670 - class_output_loss: 1.4053 - box_output_mse: 0.0670 - class_output_accuracy: 0.3755 - val_loss: 1.4302 - val_box_output_loss: 0.0831 - val_class_output_loss: 1.3472 - val_box_output_mse: 0.0831 - val_class_output_accuracy: 0.4138
# Epoch 1979/2000
# 8/8 [==============================] - 5s 645ms/step - loss: 1.4260 - box_output_loss: 0.0686 - class_output_loss: 1.3574 - box_output_mse: 0.0686 - class_output_accuracy: 0.3478 - val_loss: 1.4302 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3471 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1980/2000
# 8/8 [==============================] - 6s 772ms/step - loss: 1.4618 - box_output_loss: 0.0686 - class_output_loss: 1.3932 - box_output_mse: 0.0686 - class_output_accuracy: 0.3518 - val_loss: 1.4301 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3471 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1981/2000
# 8/8 [==============================] - 5s 627ms/step - loss: 1.4632 - box_output_loss: 0.0694 - class_output_loss: 1.3938 - box_output_mse: 0.0694 - class_output_accuracy: 0.3241 - val_loss: 1.4301 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3470 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1982/2000
# 8/8 [==============================] - 6s 782ms/step - loss: 1.4774 - box_output_loss: 0.0685 - class_output_loss: 1.4089 - box_output_mse: 0.0685 - class_output_accuracy: 0.3360 - val_loss: 1.4300 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3470 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1983/2000
# 8/8 [==============================] - 6s 660ms/step - loss: 1.4387 - box_output_loss: 0.0710 - class_output_loss: 1.3678 - box_output_mse: 0.0710 - class_output_accuracy: 0.3715 - val_loss: 1.4300 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3470 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1984/2000
# 8/8 [==============================] - 5s 630ms/step - loss: 1.4492 - box_output_loss: 0.0687 - class_output_loss: 1.3805 - box_output_mse: 0.0687 - class_output_accuracy: 0.3281 - val_loss: 1.4300 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3469 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1985/2000
# 8/8 [==============================] - 7s 890ms/step - loss: 1.4699 - box_output_loss: 0.0696 - class_output_loss: 1.4003 - box_output_mse: 0.0696 - class_output_accuracy: 0.3557 - val_loss: 1.4299 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3469 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1986/2000
# 8/8 [==============================] - 5s 605ms/step - loss: 1.4462 - box_output_loss: 0.0692 - class_output_loss: 1.3769 - box_output_mse: 0.0692 - class_output_accuracy: 0.3439 - val_loss: 1.4299 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3468 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1987/2000
# 8/8 [==============================] - 5s 660ms/step - loss: 1.4850 - box_output_loss: 0.0713 - class_output_loss: 1.4137 - box_output_mse: 0.0713 - class_output_accuracy: 0.3399 - val_loss: 1.4298 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3468 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1988/2000
# 8/8 [==============================] - 6s 763ms/step - loss: 1.4601 - box_output_loss: 0.0706 - class_output_loss: 1.3895 - box_output_mse: 0.0706 - class_output_accuracy: 0.3557 - val_loss: 1.4298 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3467 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1989/2000
# 8/8 [==============================] - 5s 607ms/step - loss: 1.4575 - box_output_loss: 0.0686 - class_output_loss: 1.3889 - box_output_mse: 0.0686 - class_output_accuracy: 0.3715 - val_loss: 1.4297 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3467 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1990/2000
# 8/8 [==============================] - 8s 1s/step - loss: 1.4936 - box_output_loss: 0.0701 - class_output_loss: 1.4235 - box_output_mse: 0.0701 - class_output_accuracy: 0.3399 - val_loss: 1.4297 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3466 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1991/2000
# 8/8 [==============================] - 5s 631ms/step - loss: 1.4845 - box_output_loss: 0.0700 - class_output_loss: 1.4145 - box_output_mse: 0.0700 - class_output_accuracy: 0.3123 - val_loss: 1.4296 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3466 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1992/2000
# 8/8 [==============================] - 5s 632ms/step - loss: 1.4824 - box_output_loss: 0.0701 - class_output_loss: 1.4123 - box_output_mse: 0.0701 - class_output_accuracy: 0.3360 - val_loss: 1.4296 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3465 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1993/2000
# 8/8 [==============================] - 7s 858ms/step - loss: 1.4739 - box_output_loss: 0.0710 - class_output_loss: 1.4029 - box_output_mse: 0.0710 - class_output_accuracy: 0.3281 - val_loss: 1.4295 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3465 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1994/2000
# 8/8 [==============================] - 5s 632ms/step - loss: 1.4753 - box_output_loss: 0.0708 - class_output_loss: 1.4045 - box_output_mse: 0.0708 - class_output_accuracy: 0.3439 - val_loss: 1.4295 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3465 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1995/2000
# 8/8 [==============================] - 6s 791ms/step - loss: 1.4417 - box_output_loss: 0.0692 - class_output_loss: 1.3724 - box_output_mse: 0.0692 - class_output_accuracy: 0.3597 - val_loss: 1.4295 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3464 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1996/2000
# 8/8 [==============================] - 6s 669ms/step - loss: 1.4984 - box_output_loss: 0.0688 - class_output_loss: 1.4296 - box_output_mse: 0.0688 - class_output_accuracy: 0.2806 - val_loss: 1.4294 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3464 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1997/2000
# 8/8 [==============================] - 5s 638ms/step - loss: 1.4632 - box_output_loss: 0.0705 - class_output_loss: 1.3927 - box_output_mse: 0.0705 - class_output_accuracy: 0.3597 - val_loss: 1.4294 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3463 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1998/2000
# 8/8 [==============================] - 7s 894ms/step - loss: 1.4521 - box_output_loss: 0.0666 - class_output_loss: 1.3854 - box_output_mse: 0.0666 - class_output_accuracy: 0.3202 - val_loss: 1.4293 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3463 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 1999/2000
# 8/8 [==============================] - 5s 635ms/step - loss: 1.4716 - box_output_loss: 0.0701 - class_output_loss: 1.4016 - box_output_mse: 0.0701 - class_output_accuracy: 0.3676 - val_loss: 1.4293 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3463 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138
# Epoch 2000/2000
# 8/8 [==============================] - 5s 684ms/step - loss: 1.4846 - box_output_loss: 0.0683 - class_output_loss: 1.4163 - box_output_mse: 0.0683 - class_output_accuracy: 0.3676 - val_loss: 1.4293 - val_box_output_loss: 0.0830 - val_class_output_loss: 1.3462 - val_box_output_mse: 0.0830 - val_class_output_accuracy: 0.4138

# %%
def plot(var1, var2, plot_name):
  # Get the loss metrics from the trained model
  c1 = history.history[var1]
  c2 = history.history[var2]

  epochs = range(len(c1))

  # Plot the metrics
  plt.plot(epochs, c1, 'b', label=var1)
  plt.plot(epochs, c2, 'r', label=var2)
  plt.title(str(plot_name))
  plt.legend()

# %%
plot('class_output_accuracy','class_output_loss','Class Output Accuracy & Class Output Loss')

# %%
plot('box_output_loss','box_output_mse','Box Output Loss vs Box Output MSE')

# %%
# Load the saved model
model.save('/content/drive/My Drive/train_25.h5')
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
# Enter your class names in this list
global label_names

# Must be same as Annotations list we used to choose the data
label_names = sorted(classes_list)

# %%
# We will use this function to make prediction on images.
def predict(image, returnimage = False,  scale = 0.9):

  # Before we can make a prediction we need to preprocess the image.
  processed_image = preprocess(image)

  # Now we can use our model for prediction
  results = model.predict(processed_image)

  # Now we need to postprocess these results.
  # After postprocessing, we can easily use our results
  label, (x1, y1, x2, y2), confidence = postprocess(image, results)

  # Now annotate the image
  cv2.rectangle(image, (x1, y1), (x2, y2), (0, 255, 100), 2)
  cv2.putText(
      image,
      '{}'.format(label, confidence),
      (x1, y2 + int(35 * scale)),
      cv2.FONT_HERSHEY_COMPLEX, scale,
      (0, 0, 255),
      2
      )

  # Show the Image with matplotlib
  plt.figure(figsize=(10,10))
  plt.imshow(image[:,:,::-1])

# %%
# This function will preprocess images.
def preprocess(img, image_size = 100):

    image = cv2.resize(img, (image_size, image_size))
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    image = image.astype("float") / 255.0

    # Expand dimensions as predict expect image in batches
    image = np.expand_dims(image, axis=0) #Expand dimension of array
    return image

# %%
def postprocess(image, results):

    # Split the results into class probabilities and box coordinates
    bounding_box, class_probs = results

    # First get the class label

    # The index of class with the highest confidence is our target class
    class_index = np.argmax(class_probs)

    # Use this index to get the class name.
    class_label = label_names[class_index]

    # Now you can extract the bounding box too.

    # Get the height and width of the actual image
    h, w = image.shape[:2]

    # Extract the Coordinates
    x1, y1, x2, y2 = bounding_box[0]

    # Convert the coordinates from relative (i.e. 0-1) to actual values
    x1 = int(w * x1)
    x2 = int(w * x2)
    y1 = int(h * y1)
    y2 = int(h * y2)

    # return the lable and coordinates
    return class_label, (x1,y1,x2,y2),class_probs

# %%
import cv2
#image = cv2.imread('/content/drive/My Drive/decay071.jpg')
image = cv2.imread('/content/aug_images/Fillings/Filliings04.jpg1.jpg')
predict(image, scale = 0.5)
# Out:
# 1/1 [==============================] - 0s 82ms/step
